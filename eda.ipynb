# %%
import pandas as pd

train = pd.read_csv('./data/raw/train.csv')
test = pd.read_csv('./data/raw/test.csv')

# %%
print(train.isna().sum())
print(test.isna().sum())
# Out:
# game_id              0
# period_id            0
# episode_id           0
# time_seconds         0
# team_id              0
# player_id            0
# action_id            0
# type_name            0
# result_name     140254
# start_x              0
# start_y              0
# end_x                0
# end_y                0
# is_home              0
# game_episode         0
# dtype: int64
# game_id         0
# game_episode    0
# path            0
# dtype: int64
